# %% [markdown]
# #데이터 사이언스#

# %% [markdown]
# ##연습 문제 2.1.1 기초문법

# %% [markdown]
# - 3×2−8÷4
# - 25×6÷3+17
# - 39021−276920÷12040
# - 26−10%6
#
# *위 식에서 %
# 는 나머지를 구하는 연산이다.*

# %%
print(3 * 3 - 8 /4)
print( 25 * 6 / 3 + 17)
print(39021 - 276920 / 12040)
print( 26 - 10%6)
# Out:
# 7.0
# 67.0
# 38998.0
# 22

# %% [markdown]
# ##연습 문제 2.1.2 연산##
# 파이썬을 계산기로 사용하여 다음 연산을 한다.
# *파이썬은 모든 연산형 괄호는 소괄호를 사용한다.*
#
# - 12−(5×7+1)
# - 5×{8+(10−6)÷2}
# - 48320−{(365−5×9)÷16}×987
# - ((34−3×7)%5+4)^2

# %%
print(12 - (5 *7 +1))
print(5 * (8 + (10 - 6) / 2))
print(488320 - ((365 - 5 *9)/16)*987)
print(((3^4 -3 *7) %5 +4)^2)
# Out:
# -24
# 50.0
# 468580.0
# 6

# %% [markdown]
# #연습문제 2.1.3 불(Bool)
# 파이썬으로 계산기로 사용하여 답이 True 인 부등식을 3개를 만든다.
#
# 파이썬으로 계산기로 사용하여 답이 False 인 부등식을 3개를 만든다.
