# %%
a = 1
print(a)
print(A)
# Out:
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-75f277185eb6> in <module>
#       1 a = 1
#       2 print(a)
# ----> 3 print(A)
#
# NameError: name 'A' is not defined

# %% [markdown]
# #식별자#
#
# a 는 변수로 **식별자** 라고 한다.
#  식별자는 영어 알파벳 or _로만 *시작*가능 하며 숫자를 추가하여 구성할 수 있다. 또한 파이썬은 식별자의 **대소문자를 구별**한다.
#
#   ---
# *참조 오류메시지*

# %%
print(type("a"))
print(type(1))
print(type(0.1))

a ="안녕하세요!"
b =1
c = 0.1

print(b + c)
print(a + " 반갑습니다.")
print(a +b)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 1.1
# 안녕하세요! 반갑습니다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-ca93872f2671> in <module>
#       9 print(b + c)
#      10 print(a + " 반갑습니다.")
# ---> 11 print(a +b)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# #자료형#
# **자료형**은 고유의 종류가 있다.
# 대표적으로 ""사이에 들어가는 텍스트형(string),
# 숫자(integer),
# 실수(float)은 전부 따로 *사용할 수 있는 연산(함수)가 다르다*
# 따라서, 이들을 혼합하여 연산(함수)를 할 수는 없다
#
# ---
