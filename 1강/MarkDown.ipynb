# %% [markdown]
# 파일 생성시 .md로 확장자명이 생성되며, 웹에 등록시 그대로 처리하게 된다.
# 범용성이 높은 문법이다. 단, 모든 HTML 태그를 지원하지는 못한다.

# %% [markdown]
# #제목1(Headeing1)#
# ##제목2(Headeing2)##
# ###제목3(Headeing3)###
# ####제목4(Headeing4)####
# #####제목5(Headeing5)#####
# ######제목6(Headeing6)######
#
# ##텍스트 내용 적기##
# 문장의 내용(텍스트)을 쭉 쓰시면 됩니다...
#
# ##줄바꿈##
#   >문장 끝에서 띄어쓰기 2번하면 됩니다.
#
#
#   첫 번째 문장
#   두 번째 문장 분명히 엔터를 친 거 같은데...
#
#   첫 번째 문장 + 띄어쓰기 두번
#   두 번째 문장의 줄바꿈
#   스페이스바를 2번 눌러야지
#   줄바꿈 처리가 됩니다 😀
#
# ##강조##
#
# *이탤릭*  별 하나로 감싸주시면 됩니다*
# **두껍게**  별 두개로 감싸주면 됩니다**
# ***두껍게 + 이탤릭***  별 세개로 감싸주면 됩니다***
# ~취소선1~ 물결표시로 감싸주면 됩니다~
# ~~취소선2~~
# <u>밑줄(underline)</u>
# #**`음영`**#
#
#
# ##목록(LIst)##
# ###순서가 있는 목록###
# 1. 순서가 있는 목록
# 2. 순서가 있는 목록
# 3. 순서가 있는 목록 (블록개념)
#
#
# 1. 순서가 있는 목록(1만 써줘도 됩니다)
# 1. 순서가 있는 목록(1만 써줘도 됩니다)
# 1. 순서가 있는 목록(1만 써줘도 됩니다)
#   엔터를 두번쳐야지 목록이 나뉘어 집니다.
#
#
# 1. 순서목록
# 1. 순서목록
#   1. 자식목록(탭추가)
#   1. 자식목록(탭추가)
# 1. 순서목록
# 1. 순서목록
#
# ##순서가 없는 목록##
#
# - 순서없는 목록
# - 순서없는 목록
#   - 자식 순서없는 목록(탭추가)
#   - 자식 순서없는 목록(탭추가)
#     - 자식의 자식 목록(탭탭추가)
#     - 자식의 자식 목록(탭탭추가)

# %% [markdown]
# ##링크(Link)##
#
# - [네이버](https://www.naver.com)
# - [구글](https://www.google.com)
# - [오픈AI](https://www.openai.com)
#
# ##이미지(Images)##
# ---
# ## [OpenAI 블로그](https://openai.com/blog/)에서 ChatGPT 관련 이미지 가져오기##
#
#
# ![Chat GPT방법론](https://cdn.openai.com/chatgpt/draft-20221129c/ChatGPT_Diagram.svg)

# %% [markdown]
# ##인용문(BlockQuote)##
# >**현재와 같은 추세로 지구의 환경오염이 지속될 때 지구의 미래는 어떻게 될까?**
# ( 💡ChatGPT 가라사대) 현재의 환경오염 추세로 지속될 경우, 지구의 미래는 매우 악화 될 것입니다. 환경오염은 기후변화, 토양, 물 공기 오염 등 많은 지역에서 악영향을 미치게 될 것입니다. 또한, 환경오염은 건강, 생태계, 경제 등에도 영향을 미치게 될 것입니다. 그래서, 지금부터 환경오염을 줄이는 노력이 필요합니다.
#
# ##인라인(inline) 코드 강조##
#
# 파이썬에서 문자열을 출력할 때는 `print` 명령을 사용한다.
#
# ##코드 표시 ##
# 터미널에서 다음 명령어를 실행해 주세요.
# ```python
# from tensorflow as tf
# print(__tf.version__)
# ```
# 다음은 자바스크립트 언어입니다.
# ```java
# const a =1 ;
# for(a < 0 ; a++){
# console.log(a)
# }
# ```
#
# 다음은 터미널 명령어 입니다.
# ```shall
# $ ls -al
# ```
#
# 다음은 HTML 언어입니다.
# ```html
# <a href="https://google.com" title ="구글로 이동"> 구글</a>
# ```

# %% [markdown]
# ##표(Table)##
#
# 주차| 주제 | 완료 여부|기간
# :--:|:--:|:--:|--:
# 1주차|파이썬 프로그래밍|X|1주
# 2주차|데이터 분석|X|1주
# 3주차|머신러닝|X|1주

# %% [markdown]
# ##원시 HTML(Raw HTML)##
# >사실 마크다운은 HTML로 전환됩니다. 마크다운에서 지원되지 안흔 일부 HTML을 활용 할 수 있습니다.
#
# 첫 번째 문장에서 가장 중요한 내용은 <u>이것</u>입니다.
# 두 번째 문장
# <img width = "100%" src="https://cdn.openai.com/chatgpt/draft-20221129c/ChatGPT_Diagram.svg"></img>
#
# ##수평선##
# ---
# 수평선은 하이픈(-)을 3번 연속 넣어주면 됩니다...
# 별표를 3번 넣어도 됩니다.
# ***
# 언더바 기호를 3번 넣어도 되고요...
# ___
